# %%
# Install packages 
# %pip install pandas numpy scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 11.1 MB 3.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 30.3 MB 41.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 309 kB 43.0 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import relavent packages 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Read data file
data = pd.read_csv("/Users/muyuanli/Desktop/ANSC 6040/project_1_ANSC_4040_dataset.csv")
# Out:
# /var/folders/5n/f_9m5grn7vq6mx7m6n8bwb6c0000gn/T/ipykernel_17618/1750957038.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/Users/muyuanli/Desktop/ANSC 6040/project_1_ANSC_4040_dataset.csv")

# %%
# Variable names and types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8495421 entries, 0 to 8495420
# Data columns (total 10 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   AnimalNumber            float64
#  1   LactationNumber         float64
#  2   DaysInMilk              float64
#  3   ReproductionStatus      object
#  4   Avgmilkflow             float64
#  5   Flow30_60Session        float64
#  6   YieldFirst2Min_Session  float64
#  7   YieldSession            float64
#  8   DurationSession_sec     int64
#  9   milking                 int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 648.1+ MB

# %%
# Changing variable names to follow naming convention
data = data.rename(columns={'Avgmilkflow': 'AvgMilkFlow'})
data = data.rename(columns={'milking': 'Milking'})
data = data.rename(columns={'DurationSession_sec': 'DurationSession_Sec'})

# %%
# Data Exploration
data.head()
# Out:
#    AnimalNumber  LactationNumber  DaysInMilk ReproductionStatus  AvgMilkFlow  \
# 0       31317.0              2.0       255.0           Pregnant     2.812273
# 1       60614.0              1.0       251.0           Pregnant     2.902991
# 2       36947.0              1.0       183.0           Pregnant     3.401943
# 3       31720.0              2.0        82.0               Bred     4.309128
# 4       23630.0              6.0       182.0           Pregnant     3.719457
#
#    Flow30_60Session  YieldFirst2Min_Session  YieldSession  \
# 0          2.898455                5.874021      8.028585
# 1          3.801104                6.372973      7.030682
# 2          3.701314                7.048825     16.374685
# 3          4.799007                8.876803     18.461209
# 4          3.701314                7.874364     13.199538
#
#    DurationSession_Sec  Milking
# 0                  168        2
# 1                  143        1
# 2                  285        3
# ...

# %%
data.describe()
# Out:
#        AnimalNumber  LactationNumber    DaysInMilk   AvgMilkFlow  \
# count  6.794418e+06     6.794418e+06  6.794414e+06  8.495249e+06
# mean   3.243931e+04     2.293987e+00  1.629297e+02  3.525963e+00
# std    5.079711e+03     1.387657e+00  1.055188e+02  7.291427e-01
# min    1.103800e+04     1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.978200e+04     1.000000e+00  7.600000e+01  2.993710e+00
# 50%    3.274300e+04     2.000000e+00  1.540000e+02  3.492661e+00
# 75%    3.484700e+04     3.000000e+00  2.370000e+02  3.991613e+00
# max    6.063000e+04     1.200000e+01  8.700000e+02  2.349608e+01
#
#        Flow30_60Session  YieldFirst2Min_Session  YieldSession  \
# count      8.495421e+06            8.495421e+06  8.495421e+06
# mean       3.751556e+00            7.491106e+00  1.392847e+01
# std        1.485679e+00            2.014112e+00  3.645984e+00
# min        0.000000e+00            2.000342e+00  5.034875e+00
# 25%        2.798665e+00            6.023707e+00  1.143053e+01
# ...

# %%
# Missing data check
data.isnull().sum()
# Out:
# AnimalNumber              1701003
# LactationNumber           1701003
# DaysInMilk                1701007
# ReproductionStatus        1701003
# AvgMilkFlow                   172
# Flow30_60Session                0
# YieldFirst2Min_Session          0
# YieldSession                    0
# DurationSession_sec             0
# Milking                         0
# dtype: int64

# %%
# Total number of cows milked
data['AnimalNumber'].nunique()
# Out:
# 9087
